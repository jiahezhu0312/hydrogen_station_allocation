# %%
from src.preprocessing.read_data import read_ald, read_tmja
from src.model.run import locate_stations
from src.utils.visualization import visualize_network
from src.utils.save_read_graph import save, read

# %%
p = 300
R = 400000
data_folder = ".\data\\"
saved_folder = './networks/'
model_name = saved_folder+f'p{p}R{R}'+'.gpickle'

# %%
tmja = read_tmja(data_folder)
ald = read_ald(data_folder)

# %%
cn = locate_stations(tmja, ald, p=70, R=400000)
# Out:
# number of additional roads 31
# 100%|██████████| 4422/4422 [02:06<00:00, 34.84it/s]
# Advanced usage:
# Problem solved in 1086808.000000 milliseconds
# Problem solved in 275492 iterations
# Percentage of demande satisfied: 0.8383485317668473
# We allocate 203 stations in this network

# %%
save(cn, model_name)
# Out:
# Graph saved

# %%
read(model_name)
